# %% [markdown]
# <a href="https://colab.research.google.com/github/Asmi1908/APS-Lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []


    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')


        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node


        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'B')

for node in result:
    print("Distance from B to", node, "=", result[node])
# Out:
# Distance from B to A = 4
# Distance from B to B = 0
# Distance from B to C = 5
# Distance from B to D = 8

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra(graph, start):
    distances = {}
    previous_nodes = {}
    visited = []
    for node in graph:
        distances[node] = float('inf')
        previous_nodes[node] = None
    distances[start] = 0
    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')
        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node
        if min_node is None:
            break
        visited.append(min_node)
        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous_nodes[neighbor] = min_node
    return distances, previous_nodes

# %%
def get_shortest_path_from_user_input(graph):
    start_node = input("Enter the start node (e.g., A, B, C, D, E, F): ").upper()
    end_node = input("Enter the end node (e.g., A, B, C, D, E, F): ").upper()
    if start_node in graph and end_node in graph:
        distances, previous_nodes = dijkstra(graph, start_node)
        path = reconstruct_path(previous_nodes, start_node, end_node)
        if path:
            total_distance = distances[end_node]
            print(f"\nShortest path from {start_node} to {end_node}:")
            print(f"  Path: {' -> '.join(path)}")
            print(f"  Total Distance: {total_distance}")
        else:
            print(f"\nNo path found from {start_node} to {end_node}.")
    elif start_node or end_node:
        print(f"Error: One or both of the entered nodes are not in the graph.")
    else:
        print("No start or end node entered.")

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10, 'E': 3, 'F':2},
'C': {'A': 2, 'B': 5, 'D': 3, 'F': 5},
'D': {'B': 10, 'C': 3,'E': 4, 'D': 2},
'E': {'D': 4, 'B': 3},
'F': {'B': 2, 'C': 5, 'D': 2}
}
result, previous_nodes_from_A = dijkstra(graph, 'A')
get_shortest_path_from_user_input(graph)
# Out:
# Enter the start node (e.g., A, B, C, D, E, F): A
# Enter the end node (e.g., A, B, C, D, E, F): E
#
# Shortest path from A to E:
#   Path: A -> B -> E
#   Total Distance: 7
